# %% [markdown]
# ### small script to generate gif images

# %%
from IPython.display import HTML ,Image

# %%
import imageio
PATH = "/home/yassinebha/Drive/QC_zooniverse/template_layout/test_data/HC0040013/"

# %%
# first image
Image(filename = PATH + "func_anat_HC0040013_mean_stereonl_nu_inv_outline.png", width=400, height=400)

# %%
# second image
Image(filename = PATH + "anat_HC0040013_nuc_stereonl_func_outline.png", width=400, height=400)

# %%
# generate gif 
command = "convert " + PATH + "func_anat_HC0040013_mean_stereonl_nu_inv_outline.png " + PATH +  "anat_HC0040013_nuc_stereonl_func_outline.png " +  PATH + "func_anat_HC0040013_mean_stereonl_nu_inv_outline.png  -delay 1 -morph 4 " + PATH + "morph_HC0040013_xp.gif"

# %%
command
# Out:
# 'convert /home/yassinebha/Drive/QC_zooniverse/template_layout/test_data/HC0040013/func_anat_HC0040013_mean_stereonl_nu_inv_outline.png /home/yassinebha/Drive/QC_zooniverse/template_layout/test_data/HC0040013/anat_HC0040013_nuc_stereonl_func_outline.png /home/yassinebha/Drive/QC_zooniverse/template_layout/test_data/HC0040013/func_anat_HC0040013_mean_stereonl_nu_inv_outline.png  -delay 1 -morph 4 /home/yassinebha/Drive/QC_zooniverse/template_layout/test_data/HC0040013/morph_HC0040013_xp.gif'

# %%
# %%bash -s "$command"
# $1

# %%
HTML('<img src="/tree/summary_X0010001_func2anat.gif"></img>')
# Out:
# <img src="/tree/summary_X0010001_func2anat.gif"></img>
