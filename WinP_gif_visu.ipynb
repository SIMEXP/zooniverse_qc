# %%
from IPython.display import HTML ,Image

# %%
PATH = "/media/yassinebha/database29/Drive/QC_zooniverse/zooniverse_gif_niak_validation/"
Image(filename = PATH + "summary_X0010001_func2anat.gif", width=100, height=100)

# %%
HTML('<img src="/tree/summary_X0010001_func2anat.gif"></img>')
# Out:
# <img src="/tree/summary_X0010001_func2anat.gif"></img>
